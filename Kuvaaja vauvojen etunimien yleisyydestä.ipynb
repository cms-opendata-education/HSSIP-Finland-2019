# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("vauvat.csv")
d.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7983aba32720> in <module>
# ----> 1 d=pd.read_csv("vauvat.csv")
#       2 d.head()
#
# NameError: name 'pd' is not defined

# %%
x=d.nimi
y=d.lkm
plt.barh(x, y, alpha=0.5, color="m")

plt.xlabel("Vauvan nimi")
plt.ylabel("Nimien lukumäärä")
plt.title("Vauvojen etunimien yleisyys")
plt.show()
