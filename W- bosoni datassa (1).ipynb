# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
d=pd.read_csv("singlemuonmet.csv")
pd.set_option("display.max_columns", None)
d.head()
# Out:
#       Run      Event type1        E1       px1        py1       pz1       pt1  \
# 0  173389  489861810     G  81.20700 -19.73920 -13.390400  77.62490  23.85240
# 1  173389  489865843     G  20.89240 -14.55570 -14.942700   1.15372  20.86030
# 2  173389  489914455     G  12.95950   3.13972  -3.732570 -12.00610   4.87749
# 3  173389  489963747     G  29.63810   6.25372  28.679100  -4.09978  29.35300
# 4  173389  489925803     G   7.01111  -1.61130   0.006709  -6.82262   1.61131
#
#        eta1      phi1  Q1      iso1    chisq1      dxy1 type2       E2  \
# 0  1.895960 -2.545530   1  0.757915  0.859481  0.001574     G   0.0000
# 1  0.055279 -2.343080   1  7.996410  0.861278  0.017863     G   0.0000
# 2 -1.632850 -0.871451  -1  2.153700  0.856005  0.093071     G   0.0000
# 3 -0.139221  1.356100   1  0.000000  0.845578 -0.060012     G   0.0000
# 4 -2.150000  3.137430  -1  0.643718  2.970230 -0.041494     G  11.2786
#
# ...

# %%
lause=2*d.pt1*d.met_et*(1-np.cos(d.phi1-d.met_phi))
mt=np.sqrt(lause)

# %%
plt.hist(mt, bins=500, range=(-10,150))
plt.show()

# %%
plt.hist(d.met_et, bins=500, range=(-5,120))
plt.show()

# %%
plt.hist(d.pt1, bins=500, range=(-5,150))
plt.show()

# %%
uusimet20=d[(d.pt2==0)&(d.pt1>20)]
uusimet30=d[(d.pt2==0)&(d.pt1>30)]
uusimet40=d[(d.pt2==0)&(d.pt1>40)]
uusimet50=d[(d.pt2==0)&(d.pt1>50)]
uusimet60=d[(d.pt2==0)&(d.pt1>60)]
uusimet70=d[(d.pt2==0)&(d.pt1>70)]
uusimet80=d[(d.pt2==0)&(d.pt1>80)]
uusimet90=d[(d.pt2==0)&(d.pt1>90)]

# %%
def transversemass (pt, met_et, phi, met_phi):
    tm = 2*pt*met_et*(1-np.cos(phi-met_phi))
    return tm

# %%
transversemass=(d.pt1, d.met_et, d.phi1, d.met_phi)
transversemass
# Out:
# (0         23.85240
#  1         20.86030
#  2          4.87749
#  3         29.35300
#  4          1.61131
#  5         20.61140
#  6         23.01130
#  7          6.48756
#  8          2.99255
#  9          8.70942
#  10         2.49077
#  11        42.64040
#  12         6.93101
#  13        30.12310
#  14        57.67720
#  15         2.79646
#  16        36.07490
#  17        20.60100
#  18        17.27660
#  19        21.41090
#  20         3.52322
#  21        38.69070
#  22        43.01020
#  23         2.44813
#  24        13.76710
#  25        38.80270
#  26        23.38560
#  27        64.43170
#  28        22.73000
#  29         4.08886
#              ...
#  457545    18.28220
#  457546     2.10737
#  457547     2.58787
#  457548    41.49220
#  457549    35.06450
#  457550    26.21740
#  457551     5.00882
#  457552    39.22980
#  457553     6.99027
#  457554    34.80190
#  457555    33.70660
#  457556    40.45200
#  457557    45.64710
#  457558     7.84650
# ...

# %%
lause2=2*uusimet20.pt1*uusimet20.met_et*(1-np.cos(uusimet20.phi1-uusimet20.met_phi))
mt2=np.sqrt(lause2)
lause3=2*uusimet30.pt1*uusimet30.met_et*(1-np.cos(uusimet30.phi1-uusimet30.met_phi))
mt3=np.sqrt(lause3)
lause4=2*uusimet40.pt1*uusimet40.met_et*(1-np.cos(uusimet40.phi1-uusimet40.met_phi))
mt4=np.sqrt(lause4)
lause5=2*uusimet50.pt1*uusimet50.met_et*(1-np.cos(uusimet50.phi1-uusimet50.met_phi))
mt5=np.sqrt(lause5)
lause6=2*uusimet60.pt1*uusimet60.met_et*(1-np.cos(uusimet60.phi1-uusimet60.met_phi))
mt6=np.sqrt(lause6)
lause7=2*uusimet70.pt1*uusimet70.met_et*(1-np.cos(uusimet70.phi1-uusimet70.met_phi))
mt7=np.sqrt(lause7)
lause8=2*uusimet80.pt1*uusimet80.met_et*(1-np.cos(uusimet80.phi1-uusimet80.met_phi))
mt8=np.sqrt(lause8)
lause9=2*uusimet90.pt1*uusimet90.met_et*(1-np.cos(uusimet90.phi1-uusimet90.met_phi))
mt9=np.sqrt(lause9)





plt.hist(mt2, bins=500, range=(-5,150), alpha=0.5, color="m", label="pt2>20")
plt.hist(mt3, bins=500, range=(-5,150), alpha=0.5, color="c", label="pt3>30")
plt.hist(mt4, bins=500, range=(-5,150), alpha=0.5, color="g", label="pt4>40")
plt.hist(mt5, bins=500, range=(-5,150), alpha=0.5, color="k", label="pt5>50")
plt.hist(mt6, bins=500, range=(-5,150), alpha=0.5, color="y", label="pt6>60")
plt.hist(mt7, bins=500, range=(-5,150), alpha=0.5, color="r", label="pt7>70")
plt.hist(mt8, bins=500, range=(-5,150), alpha=0.5, color="b", label="pt8>80")
plt.hist(mt9, bins=500, range=(-5,150), alpha=0.5, color="forestgreen", label="pt9>90")

plt.legend(loc="best")

plt.title("Transverse mass distribution for all W -> ev")
plt.xlabel("Transverse mass")
plt.ylabel("Events")
plt.show()

# %%
plt.hist(d.eta1, bins=300)

plt.show()

# %%
uusimet20eta=d[(d.pt2==0)&(d.pt1>20)&(np.abs(d.eta1)<1)]
uusimet30eta=d[(d.pt2==0)&(d.pt1>30)&(np.abs(d.eta1)<1)]
uusimet35eta=d[(d.pt2==0)&(d.pt1>35)&(np.abs(d.eta1)<1)]
uusimet40eta=d[(d.pt2==0)&(d.pt1>40)&(np.abs(d.eta1)<1)]
uusimet50eta=d[(d.pt2==0)&(d.pt1>50)&(np.abs(d.eta1)<1)]
uusimet60eta=d[(d.pt2==0)&(d.pt1>60)&(np.abs(d.eta1)<1)]

# %%
uusimet35=d[(d.pt2==0)&(d.pt1>35)&(np.abs(d.eta1)<1)]

# %%
uusimet30=d[(d.pt2==0)&(d.pt1>30)&(np.abs(d.eta1)<1)]
uusimet35=d[(d.pt2==0)&(d.pt1>35)&(np.abs(d.eta1)<1)]
uusimet40=d[(d.pt2==0)&(d.pt1>40)&(np.abs(d.eta1)<1)]



lause3=2*uusimet30.pt1*uusimet30.met_et*(1-np.cos(uusimet30.phi1-uusimet30.met_phi))
mt3=np.sqrt(lause3)
lause35=2*uusimet35.pt1*uusimet35.met_et*(1-np.cos(uusimet35.phi1-uusimet35.met_phi))
mt35=np.sqrt(lause35)
lause4=2*uusimet40.pt1*uusimet40.met_et*(1-np.cos(uusimet40.phi1-uusimet40.met_phi))
mt4=np.sqrt(lause4)

plt.hist(mt3, bins=500, range=(-5,150), alpha=0.5, color="c", label="pt3>30")
plt.hist(mt35, bins=500, range=(-5,150), alpha=0.5, color="y", label="pt35>35")
plt.hist(mt4, bins=500, range=(-5,150), alpha=0.5, color="g", label="pt4>40")

plt.legend(loc="best")

plt.title("Transverse mass distribution for all W -> ev")
plt.xlabel("Transverse mass")
plt.ylabel("Events")
plt.show()
